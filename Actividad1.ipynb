# %% [markdown]
# # Análisis de Series de Tiempo
# ## Actividad 1

# %% [markdown]
# ### 1. Generar una serie de tiempo con valores aleatorios y graficarla

# %%
import numpy
import pandas as pd
import matplotlib.pyplot as plt

# %%
X = numpy.random.normal(0, 1, size=1000)
plt.plot(X)
plt.show()

# %% [markdown]
# ### 2. Graficar una serie de tiempo con los ejemplos del repositorio

# %%
df = pd.read_csv('TECO2.2010.2021.csv')
df.head()
# Out:
#    Unnamed: 0                fechaHora  ultimoPrecio
# 0           0  2021-06-29 17:00:01.710        185.40
# 1           1  2021-06-28 17:00:03.597        184.50
# 2           2  2021-06-25 17:00:02.383        190.60
# 3           3  2021-06-24 17:00:03.497        191.45
# 4           4  2021-06-23 17:00:03.290        193.45

# %%
plt.plot(df['ultimoPrecio'])
plt.show()

# %% [markdown]
# ### 3. Redactar un informe describiendo 3 series de tiempo distintas

# %% [markdown]
# #### TECO2

# %%
df = pd.read_csv('TECO2.2010.2021.csv')
df.head()
# Out:
#    Unnamed: 0                fechaHora  ultimoPrecio
# 0           0  2021-06-29 17:00:01.710        185.40
# 1           1  2021-06-28 17:00:03.597        184.50
# 2           2  2021-06-25 17:00:02.383        190.60
# 3           3  2021-06-24 17:00:03.497        191.45
# 4           4  2021-06-23 17:00:03.290        193.45

# %%
plt.plot(df['ultimoPrecio'])
plt.show()

# %% [markdown]
# En esta serie de tiempo se presentan altas y bajas constantes, pero tiene una clara tendencia a bajar a lo largo del tiempo, aparentemente sin componentes periódicas.

# %% [markdown]
# #### RIGO

# %%
df = pd.read_csv('RIGO.2012.2021.csv')
df.head()
# Out:
#    Unnamed: 0                fechaHora  ultimoPrecio
# 0           0  2021-06-24 17:00:12.143         150.0
# 1           1  2021-06-23 12:00:20.050         150.0
# 2           2  2021-06-22 17:00:17.973         150.0
# 3           3  2021-06-18 12:00:07.107         151.0
# 4           4  2021-06-17 17:00:15.310         148.0

# %%
plt.plot(df['ultimoPrecio'])
plt.show()

# %% [markdown]
# Al igual que la serie anterior, esta serie de tiempo presenta altas y bajas constantes, con tiene una clara tendencia a bajar a lo largo del tiempo, aparentemente sin componentes periódicas. Sin embargo, en esta serie es llamativa una subida bastante considerable aproximadamente en los 500 datos, para después volver a bajar como venía sucediendo.

# %% [markdown]
# #### Airmiles

# %%
df = pd.read_csv('airmiles.csv')
df.head()
# Out:
#    Unnamed: 0  airmiles
# 0           1  30983174
# 1           2  32147663
# 2           3  38342975
# 3           4  35969113
# 4           5  36474391

# %%
plt.plot(df['airmiles'])
plt.show()

# %% [markdown]
# A diferencia de las series anteriores, en esta si parecen haber componentes periódicas, mas o menos cada 10 datos. Pese a esta periodicidad en el comportamiento, la tendencia general de la serie parece ser un crecimiento lento.
